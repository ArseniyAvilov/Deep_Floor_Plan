# %%
from net import DeepFloorModel
import torch

import warnings
warnings.filterwarnings('ignore')

# %%
model = DeepFloorModel()

# %%
test_input = torch.randn(1, 3, 512, 512)

# %%
logits_r, logits_cw = model(test_input)

# %%
print(logits_cw.size(), logits_r.size())
# Out:
# torch.Size([1, 3, 512, 512]) torch.Size([1, 9, 512, 512])

# %%
logits_r
# Out:
# tensor([[[[  6.8004,   6.8004,   7.0337,  ...,   7.0472,   6.8219,   6.8219],
#           [  6.8004,   6.8004,   7.0337,  ...,   7.0472,   6.8219,   6.8219],
#           [  7.4132,   7.4132,   7.4700,  ...,   7.4388,   7.2162,   7.2162],
#           ...,
#           [  7.0823,   7.0823,   7.3779,  ...,   7.2339,   7.4344,   7.4344],
#           [  6.8892,   6.8892,   7.2849,  ...,   7.0843,   7.1559,   7.1559],
#           [  6.8892,   6.8892,   7.2849,  ...,   7.0843,   7.1559,   7.1559]],
#
#          [[  5.0250,   5.0250,   5.0699,  ...,   5.2128,   4.8464,   4.8464],
#           [  5.0250,   5.0250,   5.0699,  ...,   5.2128,   4.8464,   4.8464],
#           [  5.4892,   5.4892,   5.3441,  ...,   5.2739,   5.1465,   5.1465],
#           ...,
#           [  5.3281,   5.3281,   5.5073,  ...,   5.5159,   5.4034,   5.4034],
#           [  5.1238,   5.1238,   5.2396,  ...,   5.3376,   4.8761,   4.8761],
#           [  5.1238,   5.1238,   5.2396,  ...,   5.3376,   4.8761,   4.8761]],
#
# ...

# %%
logits_cw
# Out:
# tensor([[[[ 0.0651,  0.0651,  0.2105,  ..., -0.0584, -0.0393, -0.0393],
#           [ 0.0651,  0.0651,  0.2105,  ..., -0.0584, -0.0393, -0.0393],
#           [ 0.4369,  0.4369,  0.5310,  ...,  0.3347,  0.2666,  0.2666],
#           ...,
#           [ 0.7236,  0.7236,  1.2784,  ...,  1.2372,  0.7598,  0.7598],
#           [ 0.0401,  0.0401,  0.6308,  ...,  0.7856,  0.8835,  0.8835],
#           [ 0.0401,  0.0401,  0.6308,  ...,  0.7856,  0.8835,  0.8835]],
#
#          [[-0.1365, -0.1365, -0.5001,  ..., -0.1640,  0.1322,  0.1322],
#           [-0.1365, -0.1365, -0.5001,  ..., -0.1640,  0.1322,  0.1322],
#           [-0.0980, -0.0980,  0.0579,  ..., -0.1853,  0.0936,  0.0936],
#           ...,
#           [-0.5318, -0.5318,  0.1621,  ..., -0.0663,  0.2400,  0.2400],
#           [ 0.0555,  0.0555, -0.1240,  ...,  0.5167,  0.1651,  0.1651],
#           [ 0.0555,  0.0555, -0.1240,  ...,  0.5167,  0.1651,  0.1651]],
#
# ...
